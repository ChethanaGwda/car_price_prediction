# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import joblib
import warnings
warnings.filterwarnings('ignore')

sns.set_style('whitegrid')

# %%
car_dataset=pd.read_csv('D:\\car_data.csv')

# %%
car_dataset.head()
# Out:
#     brand     model  year  engine_size fuel_type transmission  mileage  \
# 0  Suzuki    WagonR  2022          1.2    Hybrid       Manual     5950
# 1  Toyota   Corolla  2015          2.6  Electric          CVT   154572
# 2  Suzuki     Swift  2008          2.8    Petrol       Manual    46908
# 3  Suzuki    Cultus  2018          2.1    Diesel          CVT   165760
# 4     Kia  Sportage  2023          2.5  Electric    Automatic   143133
#
#     car_type drive_type    price
# 0  Hatchback        AWD  6280794
# 1      Truck        AWD  1363381
# 2      Sedan        AWD  7678389
# 3  Hatchback        FWD  6098764
# 4      Sedan        FWD  6689630

# %%
car_dataset.shape
# Out:
# (301, 9)

# %%
car_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    str
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    str
#  6   Seller_Type    301 non-null    str
#  7   Transmission   301 non-null    str
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), str(4)
# memory usage: 30.0 KB

# %%
car_dataset.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_dataset.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
print('\n Fuel Type:')
print(car_dataset['Fuel_Type'].value_counts())

print('\n Seller Type:')
print(car_dataset['Seller_Type'].value_counts())

print('\n Transmission:')
print(car_dataset['Transmission'].value_counts())

print('\n Owner:')
print(car_dataset['Owner'].value_counts())
# Out:
#  Fuel Type:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
#
#  Seller Type:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
#
#  Transmission:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64
#
#  Owner:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.hist(car_dataset['Selling_Price'], bins=30, color='#3498db', edgecolor='black')

plt.title('Distribution of Car Prices', fontsize=14, fontweight='bold')

plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(8, 6))

numeric_data = car_dataset.select_dtypes(include=[np.number])

correlation = numeric_data.corr()

sns.heatmap(correlation,
            annot=True,
            cmap='coolwarm',
            center=0,
            square=True,
            linewidths=1,
            fmt=".2f"
)

plt.title("Correlation Matrix Heatmap",
          fontsize=14,
          fontweight='bold',
          pad=10)

plt.show()

# %%
# Fuel Type vs Selling Price
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)

sns.boxplot(x='Fuel_Type',
            y='Selling_Price',
            data=car_dataset,
            palette='Set2')

plt.title('Fuel Type vs Selling Price',
          fontweight='bold')

plt.xlabel('Fuel Type')
plt.ylabel('Selling Price (Lakhs)')
# Out:
# Text(0, 0.5, 'Selling Price (Lakhs)')

# %%
# Transmission vs Selling Price
plt.subplot(1,2,2)

sns.boxplot(x='Transmission',
            y='Selling_Price',
            data=car_dataset,
            palette='Set1')

plt.title('Transmission vs Selling Price',
          
          fontweight='bold')

plt.xlabel('Transmission')
plt.ylabel('Selling Price (Lakhs)')

plt.show()

# %%
# Year vs Selling Price
plt.figure(figsize=(10,6))

plt.scatter(car_dataset['Year'],
            car_dataset['Selling_Price'],
            alpha=0.6,
            c='#2A9D8F')

plt.title('Car Year vs Selling Price',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Selling Price (Lakhs)')

plt.show()

# %%
# kms driven vs Selling Price
plt.figure(figsize=(6,6))

plt.scatter(car_dataset['Kms_Driven'],
            car_dataset['Selling_Price'],
            alpha=0.6,
            c='purple')

plt.title('Kilometers Driven vs Selling Price',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Kms Driven')
plt.ylabel('Selling Price (Lakhs)')

plt.show()

# %%
# Encoding

car_dataset.replace({'Fuel_Type': {'Petrol':0, 'Diesel':1, 'CNG':2}}, inplace=True)

car_dataset.replace({'Seller_Type': {'Dealer':0, 'Individual':1}}, inplace=True)

car_dataset.replace({'Transmission': {'Manual':0, 'Automatic':1}}, inplace=True)

print("Encoded Dataset")
car_dataset.head()
# Out:
# Encoded Dataset
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000         0
# 1      sx4  2013           4.75           9.54       43000         1
# 2     ciaz  2017           7.25           9.85        6900         0
# 3  wagon r  2011           2.85           4.15        5200         0
# 4    swift  2014           4.60           6.87       42450         1
#
#   Seller_Type Transmission  Owner
# 0           0            0      0
# 1           0            0      0
# 2           0            0      0
# 3           0            0      0
# 4           0            0      0

# %%
X = car_dataset.drop(['Car_Name', 'Selling_Price'], axis=1)

# %%
y = car_dataset['Selling_Price']

# %%
print(X.head())
# Out:
#    Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0  2014           5.59       27000         0           0            0      0
# 1  2013           9.54       43000         1           0            0      0
# 2  2017           9.85        6900         0           0            0      0
# 3  2011           4.15        5200         0           0            0      0
# 4  2014           6.87       42450         1           0            0      0

# %%
print(y.head())
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=2
)

print('Training samples:', [x_train.shape[0]], '(80%)')
print("Testing samples:", x_test.shape[0], '(20%)')
# Out:
# Training samples: [240] (80%)
# Testing samples: 61 (20%)

# %%
lin_reg = LinearRegression()

lin_reg.fit(x_train, y_train)

train_pred_lr = lin_reg.predict(x_train)

train_r2_lr = metrics.r2_score(y_train, train_pred_lr)

train_mae_lr = metrics.mean_absolute_error(y_train, train_pred_lr)

train_rmse_lr = np.sqrt(metrics.mean_squared_error(y_train, train_pred_lr))

print("r2 score:", train_r2_lr)

print("mae:", train_mae_lr)

print("rmse:", train_rmse_lr)
# Out:
# r2 score: 0.8838169193709792
# mae: 1.199852024214222
# rmse: 1.7909012678408935

# %%
test_pred_lr = lin_reg.predict(x_test)

test_r2_lr = metrics.r2_score(y_test, test_pred_lr)

test_mae_lr = metrics.mean_absolute_error(y_test, test_pred_lr)

test_rmse_lr = np.sqrt(metrics.mean_squared_error(y_test, test_pred_lr))

print("r2 score:", test_r2_lr)

print("mae:", test_mae_lr)

print("rmse:", test_rmse_lr)
# Out:
# r2 score: 0.8401532365378521
# mae: 1.2671998472908725
# rmse: 1.713424474241899

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(y_train, train_pred_lr, alpha=0.6, color='orange')
axes[0].plot([y_train.min(), y_train.max()],
             [y_train.min(), y_train.max()],
             'r--', lw=2)

axes[0].set_xlabel('Actual Price')
axes[0].set_ylabel('Predicted Price')
axes[0].set_title('Linear Regression - Training')


axes[1].scatter(y_test, test_pred_lr, alpha=0.6, color='green')
axes[1].plot([y_test.min(), y_test.max()],
             [y_test.min(), y_test.max()],
             'r--', lw=2)

axes[1].set_xlabel('Actual Price')
axes[1].set_ylabel('Predicted Price')
axes[1].set_title('Linear Regression - Testing')

plt.show()

# %%
# Model 2: Lasso regression

lasso_reg = Lasso(alpha=0.1)

lasso_reg.fit(x_train, y_train)

train_pred_lasso = lasso_reg.predict(x_train)

train_r2_score = metrics.r2_score(y_train, train_pred_lasso)

train_mae_lasso = metrics.mean_absolute_error(y_train, train_pred_lasso)

train_rmse_lasso = np.sqrt(metrics.mean_squared_error(y_train, train_pred_lasso))


print("r2 score:", train_r2_score)

print("mae:", train_mae_lasso)

print("rmse:", train_rmse_lasso)
# Out:
# r2 score: 0.8736452471129414
# mae: 1.1920859027644932
# rmse: 1.8676521468922174

# %%
test_pred_lasso = lasso_reg.predict(x_test)

test_r2_lasso = metrics.r2_score(y_test, test_pred_lasso)

test_mae_lasso = metrics.mean_absolute_error(y_test, test_pred_lasso)

test_rmse_lasso = np.sqrt(metrics.mean_squared_error(y_test, test_pred_lasso))

print("r2 score:", test_r2_lasso)

print("mae:", test_mae_lasso )

print("rmse:", test_rmse_lasso)
# Out:
# r2 score: 0.857876775992942
# mae: 1.2038465262647091
# rmse: 1.6156436117415025

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(y_train, train_pred_lasso, alpha=0.6, color='orange')
axes[0].plot([y_train.min(), y_train.max()],
             [y_train.min(), y_train.max()],
             'r--', lw=2)

axes[0].set_xlabel('Actual Price')
axes[0].set_ylabel('Predicted Price')
axes[0].set_title('Lasso Regression - Training')


axes[1].scatter(y_test, test_pred_lasso, alpha=0.6, color='green')
axes[1].plot([y_test.min(), y_test.max()],
             [y_test.min(), y_test.max()],
             'r--', lw=2)

axes[1].set_xlabel('Actual Price')
axes[1].set_ylabel('Predicted Price')
axes[1].set_title('Lasso Regression - Testing')

plt.show()

# %%
# Model 3: Random Forest

rf_reg = RandomForestRegressor(n_estimators=100, random_state=3)

rf_reg.fit(x_train, y_train)

train_pred_rf = rf_reg.predict(x_train)

train_r2_rf = metrics.r2_score(y_train, train_pred_rf)

train_mae_rf = metrics.mean_absolute_error(y_train, train_pred_rf)

train_rmse_rf = np.sqrt(metrics.mean_squared_error(y_train, train_pred_rf))


print("r2 score:", train_r2_rf)

print("mae:", train_mae_rf)

print("rmse:", train_rmse_rf)
# Out:
# r2 score: 0.9870633254240121
# mae: 0.24491833333333315
# rmse: 0.5976012907170353

# %%
test_pred_rf = rf_reg.predict(x_test)

test_r2_rf = metrics.r2_score(y_test, test_pred_rf)

test_mae_rf = metrics.mean_absolute_error(y_test, test_pred_rf)

test_rmse_rf = np.sqrt(metrics.mean_squared_error(y_test, test_pred_rf))


print("r2 score:", test_r2_rf)

print("mae:", test_mae_rf)

print("rmse:", test_rmse_rf)
# Out:
# r2 score: 0.9598084660643571
# mae: 0.48669836065573785
# rmse: 0.8591724314043406

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_reg.feature_importances_
}).sort_values('Importance', ascending=False)

print(feature_importance)
# Out:
#          Feature  Importance
# 1  Present_Price    0.889516
# 0           Year    0.079845
# 2     Kms_Driven    0.018930
# 3      Fuel_Type    0.003993
# 5   Transmission    0.003681
# 4    Seller_Type    0.003562
# 6          Owner    0.000473

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(y_train, train_pred_rf, alpha=0.6, color='orange')
axes[0].plot([y_train.min(), y_train.max()],
             [y_train.min(), y_train.max()],
             'r--', lw=2)

axes[0].set_xlabel('Actual Price')
axes[0].set_ylabel('Predicted Price')
axes[0].set_title('Random Forest - Training')


axes[1].scatter(y_test, test_pred_rf, alpha=0.6, color='green')
axes[1].plot([y_test.min(), y_test.max()],
             [y_test.min(), y_test.max()],
             'r--', lw=2)

axes[1].set_xlabel('Actual Price')
axes[1].set_ylabel('Predicted Price')
axes[1].set_title('Random Forest - Testing')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.barh(feature_importance['Feature'],
         feature_importance['Importance'],
         color='skyblue')

plt.xlabel('Importance')

plt.title('Feature Importance - Random Forest',
          fontsize=14,
          fontweight='bold')

plt.show()

# %%
# Model Comparison

print("Linear Regression:", test_r2_lr)

print("Lasso Regression:", test_r2_lasso)

print("Random Forest:", test_r2_rf)
# Out:
# Linear Regression: 0.8401532365378521
# Lasso Regression: 0.857876775992942
# Random Forest: 0.9598084660643571

# %%
# Save Best Model

joblib.dump(rf_reg, 'car_prediction_model.pkl')
# Out:
# ['car_prediction_model.pkl']

# %%
input_data = pd.DataFrame({
    "Year": [2019],
    "Present_Price": [7.0],
    "Kms_Driven": [50000],
    "Fuel_Type": [0],
    "Seller_Type": [1],
    "Transmission": [0],
    "Owner": [0]
})

prediction = rf_reg.predict(input_data)[0]

print(prediction)
# Out:
# 4.679499999999997
